# %% [markdown]
# # Using the nanoHUB web API

# %% [markdown]
# ## Prerequisites
# In order to run a nanoHUB tool via the web API, you need a nanoHUB account and a registered web app.
#
# Create a nanoHUB account: https://nanohub.org/register/
#
# Register a web app: https://nanohub.org/developer/api/applications/new

# %% [markdown]
# ## Introduction

# %% [markdown]
# This simple example notebook demonstrates use of the NanoHUB Composite-Laminate tool, called "complam." The tool is more fully described here: https://nanohub.org/resources/complam.
#
# (add more detailed understanding here later...)

# %%
from NanoHUB_remote import \
    authenticate, get_driver, launch_tool, get_results, extract_results

# %%
# In mysecrets.py, set your web app and account secrets.
# 
# Example, with user credentials:
# auth_data = {
#    'client_id': '',       # Get this when you register a web app
#    'client_secret': '',   # Get this when you register a web app
#    'grant_type': 'password',
#    'username': '',        # Get this when you create a nanoHUB account
#    'password': ''         # Get this when you create a nanoHUB account
# }
#
# This design is strictly for convenience so that this notebook can be 
# shared without storing any secrets.
from mysecrets import auth_data

# Authenticate; use headers in all subsequent steps
headers = authenticate(auth_data)

# %%
# The short name of the nanoHUB tool to run; this is the final stanza of
# the tool URL (e.g. https://nanohub.org/tools/complam)
tool_name = 'complam'

# Input values; keys are the labels of the inputs in the GUI
tool_inputs = {
    'E1': '132GPa',        # Longitudinal Young's Modulus
    'E2': '12.9GPa',       # Transverse Young's Modulus (in-plane)
    'h0': '0.23mm'         # Lamina thickness
}

# %%
# Generate the XML driver to run the tool with our inputs
driver_json = get_driver(tool_name, tool_inputs, headers)

# %%
# Start the simulation
session_id = launch_tool(driver_json, headers)

# %%
# This is useful for debugging
print session_id
# Out:
# 1336474

# %%
# Get the results when available
run_results = get_results(session_id, headers)

# %%
# The outputs we want; these are the labels in the result selector in the
# tool GUI 
outputs = ['Shear Modulus', 'Longitudinal Modulus']

# Get the desired outputs
results = extract_results(run_results, outputs)

# %%
print results
# Out:
# {'Shear Modulus': 35021400000.0, 'Longitudinal Modulus': 23.44}

# %%
print run_results
# Out:
# <?xml version="1.0"?>
# <run>
#     <tool>
#         <id>complam</id>
#         <name>Composite Laminate Analysis</name>
#         <version>
#             <identifier>1.2x</identifier>
#             <application>
#                 <revision>35</revision>
#                 <modified>2016-04-20 02:31:05 -0400 (Wed, 20 Apr 2016)</modified>
#                 <installed>2016-04-20 10:49:18 EDT</installed>
#                 <directory id="top">/apps/complam/r35</directory>
#                 <directory id="tool">/apps/complam/r35/rappture</directory>
#             </application>
#             <rappture>
#                 <language>matlab</language>
#                 <version>1.7</version>
#                 <revision>6697</revision>
#                 <modified>$LastChangedDate: 2016-05-04 14:27:36 -0400 (Wed, 04 May 2016) $</modified>
#             </rappture>
#         </version>
#         <title>Classical Laminate Plate Theory</title>
#         <command>run_main_clpt.sh @driver</command>
#         <uq>1</uq>
#         <cache>0</cache>
#     </tool>
#     <input>
#         <group id="tabs">
#             <group id="Material">
#                 <about>
#                     <label>Material</label>
#                 </about>
#                 <number id="E1">
#                     <about>
#                         <label>E1</label>
#                         <description>Longitudinal Young's Modulus</description>
#                     </about>
#                     <units>GPa</units>
#                     <min>0.0GPa</min>
#                     <max>500GPa</max>
#                     <default>138GPa</default>
#                     <current>132GPa</current>
#                 </number>
#                 <number id="E2">
#                     <about>
#                         <label>E2</label>
#                         <description>Transverse Young's Modulus In-Plane</description>
#                     </about>
#                     <units>GPa</units>
#                     <min>0.0GPa</min>
#                     <max>500GPa</max>
#                     <default>14.5GPa</default>
#                     <current>12.9GPa</current>
#                 </number>
#                 <number id="nu12">
#                     <about>
#                         <label>nu12</label>
#                         <description>Major In-Plane Poisson's Ratio</description>
#                     </about>
#                     <units/>
#                     <min>-1.0</min>
#                     <max>0.5</max>
#                     <default>0.21</default>
#                     <current>0.21</current>
#                 </number>
#                 <number id="G12">
#                     <about>
#                         <label>G12</label>
#                         <description>Major In-Plane Shear Modulus</description>
#                     </about>
#                     <units>GPa</units>
#                     <min>0.0GPa</min>
#                     <max>500GPa</max>
#                     <default>5.86</default>
#                     <current>5.86</current>
#                 </number>
#                 <number id="alpha1">
#                     <about>
#                         <label>alpha1</label>
#                         <description>Longitudinal Thermal Expansion Coefficient</description>
#                     </about>
#                     <units/>
#                     <min>-10e-6</min>
#                     <max>100e-6</max>
#                     <default>1e-6</default>
#                     <current>1e-6</current>
#                 </number>
#                 <number id="alpha2">
#                     <about>
#                         <label>alpha2</label>
#                         <description>Transverse Thermal Expansion Coefficient</description>
#                     </about>
#                     <units/>
#                     <min>-10e-6</min>
#                     <max>100e-6</max>
#                     <default>30e-6</default>
#                     <current>30e-6</current>
#                 </number>
#             </group>
#             <group id="Layup">
#                 <about>
#                     <label>Layup</label>
#                 </about>
#                 <number id="h0">
#                     <about>
#                         <label>h0</label>
#                         <description>Lamina Thickenss</description>
#                     </about>
#                     <units>m</units>
#                     <min>0m</min>
#                     <max>10e-3m</max>
#                     <default>0.2286mm</default>
#                     <current>0.23mm</current>
#                 </number>
#                 <string id="theta">
#                     <about>
#                         <label>theta</label>
#                         <description>Lamina Angle</description>
#                     </about>
#                     <default>[45,-45,-45,45]</default>
#                     <current>[45,-45,-45,45]</current>
#                 </string>
#             </group>
#             <group id="Loading">
#                 <about>
#                     <label>Loading</label>
#                 </about>
#                 <number id="Nx">
#                     <about>
#                         <label>Nx</label>
#                         <description>Applied Normal Edge Force in X-Direction</description>
#                     </about>
#                     <units>N/m</units>
#                     <min>-10000N/m</min>
#                     <max>10000N/m</max>
#                     <default>0N/m</default>
#                     <current>0N/m</current>
#                 </number>
#                 <number id="Ny">
#                     <about>
#                         <label>Ny</label>
#                         <description>Applied Normal Edge Force in Y-Direction</description>
#                     </about>
#                     <units>N/m</units>
#                     <min>-10000N/m</min>
#                     <max>10000N/m</max>
#                     <default>0N/m</default>
#                     <current>0N/m</current>
#                 </number>
#                 <number id="Nxy">
#                     <about>
#                         <label>Nxy</label>
#                         <description>Applied Edge Shear Force in XY-Direction</description>
#                     </about>
#                     <units>N/m</units>
#                     <min>-10000N/m</min>
#                     <max>10000N/m</max>
#                     <default>0N/m</default>
#                     <current>0N/m</current>
#                 </number>
#                 <number id="Mx">
#                     <about>
#                         <label>Mx</label>
#                         <description>Applied Bending Moment about X-Axis</description>
#                     </about>
#                     <units>N</units>
#                     <min>-10000N</min>
#                     <max>10000N</max>
#                     <default>0N</default>
#                     <current>0N</current>
#                 </number>
#                 <number id="My">
#                     <about>
#                         <label>My</label>
#                         <description>Applied Bending Moment about Y-Axis</description>
#                     </about>
#                     <units>N</units>
#                     <min>-10000N</min>
#                     <max>10000N</max>
#                     <default>0N</default>
#                     <current>0N</current>
#                 </number>
#                 <number id="Mxy">
#                     <about>
#                         <label>Mxy</label>
#                         <description>Applied Twisting Moment</description>
#                     </about>
#                     <units>N</units>
#                     <min>-10000N</min>
#                     <max>10000N</max>
#                     <default>0N</default>
#                     <current>0N</current>
#                 </number>
#                 <number id="Ti">
#                     <about>
#                         <label>Ti</label>
#                         <description>Initial Temperature</description>
#                     </about>
#                     <units>C</units>
#                     <min>-273.15C</min>
#                     <max>500C</max>
#                     <default>0C</default>
#                     <current>0C</current>
#                 </number>
#                 <number id="Tf">
#                     <about>
#                         <label>Tf</label>
#                         <description>Final Temperature</description>
#                     </about>
#                     <units>C</units>
#                     <min>-273.15C</min>
#                     <max>500C</max>
#                     <default>0C</default>
#                     <current>0C</current>
#                 </number>
#                 <!--
#           <integer id="xRes">
#               <about>
#                   <label>xRes</label>
#                   <description>Number of points in the x-direction where the solution will be evaluated</description>
#               </about>
#               <min>10</min>
#               <max>1001</max>
#               <default>51</default>
#           </integer>
#
#           <integer id="yRes">
#               <about>
#                   <label>yRes</label>
#                   <description>Number of points in the y-direction where the solution will be evaluated</description>
#               </about>
#               <min>10</min>
#               <max>1001</max>
#               <default>51</default>
#           </integer>
#           -->
#             </group>
#         </group>
#         <!-- This group of groups is drawn as a set of tabs -->
#     </input>
#     <output>
#         <string id="Ins">
#             <current>E1 	     1.32e+11
#  E2 	     1.29e+10
#  nu12 	         0.21
#  G12 	         5.86
#  alpha1 	        1e-06
#  alpha2 	        3e-05
#  h0 	      0.00023
#  Nx 	            0
#  Ny 	            0
#  Nxy 	            0
#  Mx 	            0
#  My 	            0
#  Mxy 	            0
#  dT 	            0Theta 45 -45 -45  45</current>
#             <about>
#                 <label>Inputs</label>
#             </about>
#         </string>
#         <curve id="sigX">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Stress Through Thickness, Laminate Coordinate System</group>
#                 <label>sigma_{x}</label>
#             </about>
#         </curve>
#         <curve id="sigY">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Stress Through Thickness, Laminate Coordinate System</group>
#                 <label>sigma_{y}</label>
#             </about>
#         </curve>
#         <curve id="tauXY">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Stress Through Thickness, Laminate Coordinate System</group>
#                 <label>tau_{xy}</label>
#             </about>
#             <xaxis>
#                 <label>Stess</label>
#                 <units>Pa</units>
#             </xaxis>
#             <yaxis>
#                 <label>Through Thickness Location z/h0</label>
#                 <units>-</units>
#             </yaxis>
#         </curve>
#         <curve id="sig1">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Stress Through Thickness, Material Coordinate System</group>
#                 <label>sigma_{1}</label>
#             </about>
#         </curve>
#         <curve id="sig2">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Stress Through Thickness, Material Coordinate System</group>
#                 <label>sigma_{2}</label>
#             </about>
#         </curve>
#         <curve id="tau12">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Stress Through Thickness, Material Coordinate System</group>
#                 <label>tau_{12}</label>
#             </about>
#             <xaxis>
#                 <label>Stess</label>
#                 <units>Pa</units>
#             </xaxis>
#             <yaxis>
#                 <label>Through Thickness Location z/h0</label>
#                 <units>-</units>
#             </yaxis>
#         </curve>
#         <curve id="epsX">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0             0
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Strain Through Thickness, Laminate Coordinate System</group>
#                 <label>epsilon_{x}</label>
#             </about>
#         </curve>
#         <curve id="epsY">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0             0
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Strain Through Thickness, Laminate Coordinate System</group>
#                 <label>epsilon_{y}</label>
#             </about>
#         </curve>
#         <curve id="gammaXY">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0             0
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Strain Through Thickness, Laminate Coordinate System</group>
#                 <label>gamma_{xy}</label>
#             </about>
#             <xaxis>
#                 <label>Strain</label>
#                 <units>-</units>
#             </xaxis>
#             <yaxis>
#                 <label>Through Thickness Location z/h0</label>
#                 <units>-</units>
#             </yaxis>
#         </curve>
#         <curve id="eps1">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Strain Through Thickness, Material Coordinate System</group>
#                 <label>epsilon_{1}</label>
#             </about>
#         </curve>
#         <curve id="eps2">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Strain Through Thickness, Material Coordinate System</group>
#                 <label>epsilon_{2}</label>
#             </about>
#         </curve>
#         <curve id="gamma12">
#             <component>
#                 <xy>           0            -2
#            0            -1
#            0            -1
#            0             0
#            0             0
#            0             1
#            0             1
#            0             2
# </xy>
#             </component>
#             <about>
#                 <group>Strain Through Thickness, Material Coordinate System</group>
#                 <label>gamma_{12}</label>
#             </about>
#             <xaxis>
#                 <label>Strain</label>
#                 <units>-</units>
#             </xaxis>
#             <yaxis>
#                 <label>Through Thickness Location z/h0</label>
#                 <units>-</units>
#             </yaxis>
#         </curve>
#         <string id="Laminate">
#             <about>
#                 <label>Effective Laminate Properties</label>
#             </about>
#             <current>Ex =        23.44
#  Ey =        23.44
#  nuxy =            1
#  Gxy =  3.50214e+10
#  alphax =  4.01134e-06
#  alphay =  4.01137e-06
#  alphaxy =            0</current>
#         </string>
#         <number id="Ex">
#             <current>       23.44
# </current>
#             <about>
#                 <label>Longitudinal Modulus</label>
#             </about>
#             <units>Pa</units>
#         </number>
#         <number id="Ey">
#             <current>       23.44
# </current>
#             <about>
#                 <label>Transverse Modulus</label>
#             </about>
#             <units>Pa</units>
#         </number>
#         <number id="Gxy">
#             <current> 3.50214e+10
# </current>
#             <about>
#                 <label>Shear Modulus</label>
#             </about>
#             <units>Pa</units>
#         </number>
#         <number id="nu">
#             <current>           1
# </current>
#             <about>
#                 <label>Poisson ratio</label>
#             </about>
#         </number>
#         <number id="alphax">
#             <current> 4.01134e-06
# </current>
#             <about>
#                 <label>Thermal Expansion (x)</label>
#             </about>
#         </number>
#         <number id="alphay">
#             <current> 4.01137e-06
# </current>
#             <about>
#                 <label>Thermal Expansion (y)</label>
#             </about>
#         </number>
#         <number id="alphaxy">
#             <current>           0
# </current>
#             <about>
#                 <label>Thermal Expansion (xy)</label>
#             </about>
#         </number>
#         <time>Fri Jul 20 08:56:09 AM EDT 2018</time>
#         <status>ok</status>
#         <user>dcelbert</user>
#         <host/>
#         <session>1336474</session>
#         <filename>/home/nanohub/dcelbert/data/results/1336474/run153209136982538.xml</filename>
#         <version>1.7</version>
#     </output>
# </run>
