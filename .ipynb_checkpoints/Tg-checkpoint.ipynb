# %% [markdown]
# # Calculate the glass transition temperature, $T_g$, of an atomistic amorphous system using simulation tools at nanoHUB.org

# %%
# System setup
import sys, os, tempfile

#sys.path.append('/apps/share64/debian7/ipynb_tools')
sys.path.append('/storage/davidelbert/persistent/NanoHUB_API_Example/NanoHUB_remote')

# Run this calculation in a temporary directory
workdir = tempfile.mkdtemp(dir=os.getcwd())
#%cd $workdir

# %%
from NanoHUB_remote import \
    authenticate, get_driver, launch_tool, get_results, extract_results

from mysecrets import auth_data

# Authenticate; use headers in all subsequent steps
headers = authenticate(auth_data)

# %%
# The short name of the nanoHUB tool to run; this is the final stanza of
# the tool URL (e.g. https://nanohub.org/tools/complam)
tool_name = 'polymod'

# Input values; keys are the labels of the inputs in the GUI
tool_inputs = {
    'Polymer': 'PMMA (atactic)',  # Select the polymer
    'Monomers per chain': 10,   # Set the length of the chains (monomers per chain)
    'Number of chains': 30,  # Set the number of chains
    'Simulation choice': 'LAMMPS input files only',
    'Minimization levels': 3,
    'Minimization steps': 5000,
    'Ensemble': 'npt',
    'Number of MD steps': 10000,
    'Temperature': 800
    
}

# %%
# Generate the XML driver to run the tool with our inputs
driver_json = get_driver(tool_name, tool_inputs, headers)

# %%
# Start the simulation
session_id = launch_tool(driver_json, headers)
print session_id
# Out:
# 1336183

# %%
run_results = get_results(session_id, headers)

# %%
print run_results
# Out:
# <?xml version="1.0"?>
# <run>
#     <tool>
#         <id>polymod</id>
#         <name>Polymer Modeler</name>
#         <version>
#             <identifier>3.36</identifier>
#             <application>
#                 <revision>457</revision>
#                 <modified>2018-04-05 08:47:25 -0400 (Thu, 05 Apr 2018)</modified>
#                 <installed>2018-04-06 10:25:51 EDT</installed>
#                 <directory id="top">/apps/polymod/r457</directory>
#                 <directory id="tool">/apps/polymod/r457/rappture</directory>
#             </application>
#             <rappture>
#                 <version>1.7</version>
#                 <revision>6697</revision>
#             </rappture>
#         </version>
#         <title>Polymer Modeler</title>
#         <about/>
#         <command>ruby @tool/../bin/polymod.rb @driver</command>
#         <layout>wizard</layout>
#     </tool>
#     <input>
#         <phase id="structure_phase">
#             <about>
#                 <label>Structure</label>
#                 <description>Specify polymer structure</description>
#             </about>
#             <choice id="structure_choice">
#                 <about>
#                     <label>Structure options</label>
#                     <description>Choose to build polymers or use pre-built polymers</description>
#                 </about>
#                 <option>
#                     <about>
#                         <label>Build polymer</label>
#                         <description>Construct polymer chains</description>
#                     </about>
#                     <value>build</value>
#                 </option>
#                 <option>
#                     <about>
#                         <label>Use pre-built polymers</label>
#                         <description/>
#                     </about>
#                     <value>prebuilt</value>
#                 </option>
#                 <option>
#                     <about>
#                         <label>Upload LAMMPS data file from previous run</label>
#                         <description>Use a LAMMPS data file from a previously built structure.  WARNING: this file MUST have the correct pair coefficients!  A data file created by this builder will be correct; other LAMMPS data files may not have the necessary information.</description>
#                     </about>
#                     <value>upload</value>
#                 </option>
#                 <default>build</default>
#                 <current>build</current>
#             </choice>
#             <group id="pre-built_polymer">
#                 <about>
#                     <enable>input.phase(structure_phase).choice(structure_choice) == "prebuilt"</enable>
#                     <label>Pre-built polymers</label>
#                     <description>Select a pre-built polymer</description>
#                 </about>
#                 <loader id="prebuilt_loader">
#                     <about>
#                         <label>Prebuilt Structures</label>
#                         <description>A list of structures that have already been created and are ready to use in LAMMPS.</description>
#                     </about>
#                     <new>prebuilt/new.xml</new>
#                     <example>prebuilt/*/*.xml</example>
#                     <default>new.xml</default>
#                     <current>new.xml</current>
#                 </loader>
#                 <structure id="prebuilt_structure">
#                     <default>
#                         <components>
#                             <molecule>
#                                 <pdb/>
#                             </molecule>
#                         </components>
#                     </default>
#                     <current/>
#                 </structure>
#             </group>
#             <group id="upload_structure">
#                 <about>
#                     <enable>input.phase(structure_phase).choice(structure_choice) == "upload"</enable>
#                     <label>Upload structure</label>
#                 </about>
#                 <string id="upload_data_file">
#                     <about>
#                         <label>Upload LAMMPS data file</label>
#                         <description>Upload a LAMMPS data file produced by a previous build with this tool, with the "Pair Coeffs" section removed.</description>
#                         <hints>The data file must not have a "Pair Coeffs" section.</hints>
#                     </about>
#                     <size>50x10</size>
#                 </string>
#                 <string id="upload_pair_coeffs">
#                     <about>
#                         <label>Upload LAMMPS pair coefficients</label>
#                         <description>Upload pair coefficients produced by a previous build with this tool</description>
#                         <hints>Get the pair coefficients from a previous input file.</hints>
#                     </about>
#                     <size>50x10</size>
#                 </string>
#             </group>
#             <group id="build_polymer">
#                 <about>
#                     <enable>input.phase(structure_phase).choice(structure_choice) == "build"</enable>
#                     <label>Build polymer</label>
#                     <description>Construct polymer chains</description>
#                 </about>
#                 <group id="model_tab">
#                     <about>
#                         <label>Monomer structures</label>
#                         <description>Specify chain properties</description>
#                     </about>
#                     <loader id="polymer_loader">
#                         <about>
#                             <label>Polymer</label>
#                             <description>Select a pre-built monomer used to build chains.</description>
#                         </about>
#                         <upload>
#                             <to>input.phase(structure_phase).group(build_polymer).group(model_tab).group(zmatrix_group).string(zmatrix)</to>
#                         </upload>
#                         <download>
#                             <from>input.phase(structure_phase).group(build_polymer).group(model_tab).group(zmatrix_group).string(zmatrix)</from>
#                         </download>
#                         <new>polymers/new.xml</new>
#                         <example>polymers/*.xml</example>
#                         <default>PMMA_isotactic.xml</default>
#                         <current>PMMA (atactic)</current>
#                     </loader>
#                     <group id="zmatrix_group">
#                         <about>
#                             <label>Monomer</label>
#                             <description>Specify repeated unit(s)</description>
#                         </about>
#                         <integer id="num_zmatrices">
#                             <about>
#                                 <label>Number of monomer types</label>
#                                 <description>Enter the number of monomer types which can be used to build chains.  Note that this is NOT the number of monomers in a chain.</description>
#                             </about>
#                             <default>1</default>
#                             <current>1</current>
#                         </integer>
#                         <choice id="monomer_format">
#                             <about>
#                                 <label>Monomer format</label>
#                             </about>
#                             <option>
#                                 <about>
#                                     <label>pdb</label>
#                                 </about>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>xyz</label>
#                                 </about>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>zm</label>
#                                 </about>
#                             </option>
#                             <default>zm</default>
#                             <current>zm</current>
#                         </choice>
#                         <string id="zmatrix">
#                             <about>
#                                 <label>Monomer atoms</label>
#                                 <description>Atomic coordinates for a monomer in PDB, XYZ, or z-matrix format.
#
# If format is z-matrix, the first line must be the number of backbone atoms (see the PMMA examples).  Multiple monomers may be defined in z-matrix format, separated by lines that give the number of backbone atoms.  The N backbone atoms must be the first N lines in a z-matrix.
#                         </description>
#                                 <hints>Right click to upload</hints>
#                             </about>
#                             <size>40x10</size>
#                         </string>
#                         <integer id="head_index">
#                             <about>
#                                 <label>Head atom</label>
#                                 <description>Line number of the head atom</description>
#                                 <enable>input.phase(structure_phase).group(build_polymer).group(model_tab).group(zmatrix_group).choice(monomer_format) == "pdb" || input.phase(structure_phase).group(build_polymer).group(model_tab).group(zmatrix_group).choice(monomer_format) == "xyz"</enable>
#                             </about>
#                             <default>1</default>
#                             <min>1</min>
#                             <current>1</current>
#                         </integer>
#                         <integer id="tail_index">
#                             <about>
#                                 <label>Tail atom</label>
#                                 <description>Line number of the tail atom</description>
#                                 <enable>input.phase(structure_phase).group(build_polymer).group(model_tab).group(zmatrix_group).choice(monomer_format) == "pdb" || input.phase(structure_phase).group(build_polymer).group(model_tab).group(zmatrix_group).choice(monomer_format) == "xyz"</enable>
#                             </about>
#                             <default>4</default>
#                             <min>1</min>
#                             <current>4</current>
#                         </integer>
#                     </group>
#                     <boolean id="specify_arrangements">
#                         <about>
#                             <label>Specify monomer arrangements</label>
#                             <description/>
#                             <default>no</default>
#                             <current>no</current>
#                         </about>
#                     </boolean>
#                     <group id="monomer_arrangement_group">
#                         <about>
#                             <enable>input.phase(structure_phase).group(build_polymer).group(model_tab).boolean(specify_arrangements)</enable>
#                             <label>Monomer arrangments</label>
#                             <description>Specify how monomers are arranged when building chains</description>
#                         </about>
#                         <integer id="num_arrangements">
#                             <about>
#                                 <label>Number of possible arrangments</label>
#                                 <description>Specify the number of possible arrangments, patterns, or probabilities/weights used to determine monomer arrangements in chains</description>
#                             </about>
#                             <default>1</default>
#                             <current>1</current>
#                         </integer>
#                         <string id="arrangement_str">
#                             <about>
#                                 <label>Arrangement specification</label>
#                                 <description>
# The arrangement specification begins with a "0" or "1"; "0"
# indicates the arrangement is a pattern (e.g. copolymer or
# syndiotactic chain), while "1" indicates the arrangement is
# based on probabilities (e.g. atactic chain).  For a pattern,
# the next line should be the number of monomers in the
# arrangement followed by a third line with the monomer indices
# (in the order of the zmatrices specified above).  For
# probabilities, the next line specifies the probabilities for
# each monomer, in the order of zmatrices given above.
#
# For example, to specify two different arrangements for two
# monomers, a repeating pattern and a random probability
# arrangement, use the following string:
#
# 0        # First arrangement: a pattern
# 2        #    Two monomers in this arrangement
# 1 2      #    First monomer, second monomer, repeat
# 1        # Second arrangment: probabilisitc
# 0.5 0.5  #    Each monomer has equal probability
#
# The relative probability of each arrangement is determined
# below, in Arrangement probabilities.
#                         </description>
#                             </about>
#                             <default>0  # Pattern
# 1   # One monomer in the pattern
# 1   # Monomer 1, repeat
#                      </default>
#                             <size>40x10</size>
#                             <current>0  # Pattern
# 1   # One monomer in the pattern
# 1   # Monomer 1, repeat
#                      </current>
#                         </string>
#                         <string id="arrangement_prob_str">
#                             <about>
#                                 <label>Arrangement probabilities</label>
#                                 <description>
# For each arrangement specified above in Arrangement specification,
# give the relative probabilities (sum 1.0) of each arrangement in
# the order specified.  For example, in the two-arrangement example
# in the Arrangment specification description, we can give the two
# arrangements equal probability with the string "0.5 0.5".  Or we
# can favor the first arrangement, the repeating pattern "1 2" with
# the probability string "0.7 0.3".
#                         </description>
#                             </about>
#                             <default>1.0   # Only one arrangement</default>
#                             <size>40x1</size>
#                             <current>1.0   # Only one arrangement</current>
#                         </string>
#                     </group>
#                     <number id="bond_length">
#                         <about>
#                             <label>Bond length between monomers</label>
#                             <description>Bond length used when joining a new monomer to an existing chain</description>
#                         </about>
#                         <units>A</units>
#                         <default>1.53</default>
#                         <current>1.53</current>
#                     </number>
#                     <number id="bond_scale_factor">
#                         <about>
#                             <label>Bond scale factor</label>
#                             <description>The z-matrix description of a monomer does not always include all the relevant bonds, especially for systems with rings.  The builder will search for extra bonds, using this factor times the equilibrium bond length between two atoms.  Any pair of atoms within that distance, and not explicitly bonded in the z-matrix, will be bonded.</description>
#                         </about>
#                         <units/>
#                         <default>1.1</default>
#                         <current>1.1</current>
#                     </number>
#                     <integer id="num_monomers">
#                         <about>
#                             <label>Monomers per chain</label>
#                             <description>Number of monomers used to construct a chain</description>
#                         </about>
#                         <min>1</min>
#                         <default>40</default>
#                         <current>10</current>
#                     </integer>
#                     <integer id="num_chains">
#                         <about>
#                             <label>Number of chains</label>
#                             <description>Number of chains constructed, each with the specified number of monomers</description>
#                         </about>
#                         <min>1</min>
#                         <default>1</default>
#                         <current>30</current>
#                     </integer>
#                 </group>
#                 <group id="energy_tab">
#                     <about>
#                         <label>Configurations</label>
#                         <description>Specify chain configurations</description>
#                     </about>
#                     <choice id="configuration_choice">
#                         <about>
#                             <label>Chain configurations</label>
#                             <description>Choose the algorithm used to select chain configurations</description>
#                         </about>
#                         <option>
#                             <about>
#                                 <label>Configurational bias Monte Carlo</label>
#                             </about>
#                             <value>cbmc</value>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>Freely rotating</label>
#                             </about>
#                             <value>free</value>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>Rod-like (fixed torsion angles)</label>
#                             </about>
#                             <value>rod</value>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>Excluded volume</label>
#                             </about>
#                             <value>exc</value>
#                         </option>
#                         <default>cbmc</default>
#                         <current>cbmc</current>
#                     </choice>
#                     <group id="CBMC">
#                         <about>
#                             <label>Configurational bias Monte Carlo</label>
#                             <enable>input.phase(structure_phase).group(build_polymer).group(energy_tab).choice(configuration_choice) == "cbmc"</enable>
#                         </about>
#                         <loader id="torsion_loader">
#                             <about>
#                                 <label>Covalent torsion energies</label>
#                                 <description>Select the specification of energy or probability for given torsion angles</description>
#                             </about>
#                             <example>torsions/*.xml</example>
#                             <default>sp3.xml</default>
#                             <current>sp3.xml</current>
#                         </loader>
#                         <choice id="covalent_energy">
#                             <about>
#                                 <label>hidden</label>
#                                 <enable>no</enable>
#                             </about>
#                             <option>
#                                 <about>
#                                     <label>energy</label>
#                                 </about>
#                                 <value>energy</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>prob</label>
#                                 </about>
#                                 <value>prob</value>
#                             </option>
#                             <default>energy</default>
#                             <current>energy</current>
#                         </choice>
#                         <string id="torsion_input">
#                             <about>
#                                 <label>Torsion specification</label>
#                                 <description>Angle - energy or angle-probabilities pairs, given in degrees and kcal/mol, separated by newlines.  For example,
#  0   0.5
# 90   0.8
# 180  0.1
# 270  0.8
# specifies that the allowed values for torsion angles which are allowed to vary are 0, 90, 180, and 270 degrees, with associated energies of 0.5, 0.8, 0.1, and 0.8 kcal/mol, respectively.  Thus, 180 degrees will be the most probable torsion angle value, and the probabilities of the other angles are calculated using exp(-(E-0.1)/kT).  All probabilities are subsequently normalized.
# </description>
#                                 <hints>angle-energy or angle-probability</hints>
#                             </about>
#                             <size>30x5</size>
#                             <default/>
#                             <current>None</current>
#                         </string>
#                         <number id="cmbc_cutoff">
#                             <about>
#                                 <label>Cutoff radius</label>
#                                 <description>Non-bond interactions cutoff radius</description>
#                             </about>
#                             <units>A</units>
#                             <default>5.0</default>
#                             <min>3.0</min>
#                             <current>5.0</current>
#                         </number>
#                         <number id="cmbc_temperature">
#                             <about>
#                                 <label>Monte Carlo temperature</label>
#                                 <description>Temperature used in calculating Boltzmann probabilities</description>
#                             </about>
#                             <units>K</units>
#                             <default>300</default>
#                             <min>1.0</min>
#                             <current>300</current>
#                         </number>
#                         <integer id="cmbc_steps">
#                             <about>
#                                 <label>Monte Carlo torsion steps</label>
#                                 <description>Number of configurations per torsion, chosen according to covalent torsion energies, to minimize interaction energy</description>
#                             </about>
#                             <default>50</default>
#                             <min>1</min>
#                             <current>50</current>
#                         </integer>
#                         <integer id="cmbc_delta_steps">
#                             <about>
#                                 <label>Random walk steps</label>
#                                 <description>After choosing a torsion angle with Monte Carlo torsion steps, above, perform this many random walk steps around the chosen angle in another Monte Carlo minimization</description>
#                             </about>
#                             <default>10</default>
#                             <min>0</min>
#                             <current>10</current>
#                         </integer>
#                         <number id="cmbc_step_size">
#                             <about>
#                                 <label>Random walk step size</label>
#                                 <description>Step size in degrees used when exploring torsion configurations</description>
#                             </about>
#                             <units/>
#                             <default>3.0</default>
#                             <min>0.5</min>
#                             <current>3.0</current>
#                         </number>
#                     </group>
#                     <group id="rodlike">
#                         <about>
#                             <label>Rod-like</label>
#                             <enable>input.phase(structure_phase).group(build_polymer).group(energy_tab).choice(configuration_choice) == "rod"</enable>
#                         </about>
#                         <number id="angle">
#                             <about>
#                                 <label>Angle</label>
#                                 <description>Fixed torsion angle</description>
#                             </about>
#                             <units/>
#                             <default>180.0</default>
#                             <min>0.0</min>
#                             <max>359.0</max>
#                             <current>180.0</current>
#                         </number>
#                     </group>
#                     <group id="excluded">
#                         <about>
#                             <label>Excluded volume</label>
#                             <enable>input.phase(structure_phase).group(build_polymer).group(energy_tab).choice(configuration_choice) == "exc"</enable>
#                         </about>
#                         <number id="radius">
#                             <about>
#                                 <label>Hard sphere radius</label>
#                                 <description>Atoms can not be closer than this distance.</description>
#                             </about>
#                             <units>A</units>
#                             <default>3.0</default>
#                             <min>1.0</min>
#                             <current>3.0</current>
#                         </number>
#                         <integer id="trials">
#                             <about>
#                                 <label>Max trials</label>
#                                 <description>Maximum number of trials per torsion</description>
#                             </about>
#                             <default>50</default>
#                             <min>1</min>
#                             <current>50</current>
#                         </integer>
#                     </group>
#                     <choice id="torsion_selection">
#                         <about>
#                             <label>Torsion selection</label>
#                             <description>Choose the torsion angles to which the algorithms selected above are applied</description>
#                         </about>
#                         <option>
#                             <about>
#                                 <label>Apply to all torsions in backbone</label>
#                             </about>
#                             <value>all</value>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>Apply only to torsions between monomers</label>
#                             </about>
#                             <value>between</value>
#                         </option>
#                         <default>between</default>
#                         <current>between</current>
#                     </choice>
#                 </group>
#                 <group id="system_tab">
#                     <about>
#                         <label>Simulation cell</label>
#                         <description>Specify parameters of the system in which the chains are constructed</description>
#                     </about>
#                     <group id="volume_group">
#                         <about>
#                             <label>Volume</label>
#                             <description>Specify system volume</description>
#                         </about>
#                         <choice id="volume_choice">
#                             <about>
#                                 <label>System volume</label>
#                                 <description>Specify system volume using polymer density or explicitly defining the simulation cell size</description>
#                             </about>
#                             <option>
#                                 <about>
#                                     <label>Specify polymer density</label>
#                                     <description/>
#                                 </about>
#                                 <value>density</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>Specify cell dimensions</label>
#                                     <description/>
#                                 </about>
#                                 <value>cell</value>
#                             </option>
#                             <default>density</default>
#                             <current>density</current>
#                         </choice>
#                         <number id="polymer_density">
#                             <about>
#                                 <enable>input.phase(structure_phase).group(build_polymer).group(system_tab).group(volume_group).choice(volume_choice) == "density"</enable>
#                                 <label>Density (g/cm^3)</label>
#                                 <description>Polymer density in g/cm^3</description>
#                             </about>
#                             <default>0.5</default>
#                             <min>0.01</min>
#                             <max>1.0</max>
#                             <current>0.5</current>
#                         </number>
#                         <number id="box_size">
#                             <about>
#                                 <enable>input.phase(structure_phase).group(build_polymer).group(system_tab).group(volume_group).choice(volume_choice) == "cell"</enable>
#                                 <label>Cell dimensions</label>
#                                 <description>Dimension of an edge of the cubic computational cell, in Angstroms</description>
#                             </about>
#                             <min>1.0</min>
#                             <default>50.0</default>
#                             <current>50.0</current>
#                         </number>
#                     </group>
#                 </group>
#                 <group id="output_tab">
#                     <about>
#                         <label>Output</label>
#                         <description>Specify desired output options</description>
#                     </about>
#                     <boolean id="view_chains">
#                         <about>
#                             <label>View constructed chains</label>
#                             <description>Show molecular visualization of chains; this may be slow for many long chains</description>
#                         </about>
#                         <default>yes</default>
#                         <current>yes</current>
#                     </boolean>
#                     <boolean id="view_rotation">
#                         <about>
#                             <label>Animate rotation</label>
#                             <description>Show animation of one monomer rotating with respect to another</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <boolean id="plot_length">
#                         <about>
#                             <label>Plot mean end-to-end length</label>
#                             <description>Plot mean end-to-end chain length as a function of the number of backbone bonds</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <boolean id="plot_ideal_length">
#                         <about>
#                             <enable>input.phase(structure_phase).group(build_polymer).group(output_tab).boolean(plot_length)</enable>
#                             <label>Plot ideal end-to-end length</label>
#                             <description>Plot ideal end-to-end chain length along with mean end-to-end chain length</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <group id="theor_length_group">
#                         <about>
#                             <enable>input.phase(structure_phase).group(build_polymer).group(output_tab).boolean(plot_length) &amp;&amp; input.phase(structure_phase).group(build_polymer).group(output_tab).boolean(plot_ideal_length)</enable>
#                             <label>Ideal end-to-end chain length</label>
#                             <description>Define a theoretical chain length expression as a function of the number of backbone bonds, n</description>
#                         </about>
#                         <note>
#                             <contents>file://theor_length.html</contents>
#                         </note>
#                         <number id="theor_length_pref">
#                             <about>
#                                 <label>Prefactor</label>
#                                 <description>Coeffiecient, C, of the theoretical end-to-end chain length expression</description>
#                             </about>
#                             <default>2.28</default>
#                             <current>2.28</current>
#                         </number>
#                         <number id="theor_length_exp">
#                             <about>
#                                 <label>Power</label>
#                                 <description>Exponent, p, of the theoretical end-to-end chain length expression</description>
#                             </about>
#                             <default>0.5</default>
#                             <current>0.5</current>
#                         </number>
#                     </group>
#                     <boolean id="plot_length_histo">
#                         <about>
#                             <label>End-to-end length histogram</label>
#                             <description>Show histogram of end-to-end chain lengths</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <boolean id="plot_torsion_histo">
#                         <about>
#                             <label>Torsion angle histogram</label>
#                             <description>Show histogram of torsion angle selections</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                 </group>
#                 <group id="advanced_tab">
#                     <about>
#                         <label>Advanced</label>
#                         <description/>
#                     </about>
#                     <integer id="rng_seed">
#                         <about>
#                             <label>Random number generator seed</label>
#                             <description>If this value is non-zero, use the value as the RNG seed.  By default this is zero and a default seed (the current time) is used.  The RNG seed is included in the output log, so you can reproduce exactly the same system by using that seed as this input in a subsequent simulation.</description>
#                         </about>
#                         <default>0</default>
#                         <current>0</current>
#                     </integer>
#                     <boolean id="write_zmatrices">
#                         <about>
#                             <label>Write z-matrices</label>
#                             <description>Include all z-matrices in the output log</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <boolean id="write_builder_input">
#                         <about>
#                             <label>Write builder input file</label>
#                             <description>Add the polymer builder input file to the output</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <boolean id="multiple_torsions">
#                         <about>
#                             <label>Configure multiple torsions</label>
#                             <description>Specify custom torsion energies or probabilities for individual torsions.  By default, all the torsion options in the Configurations tab apply to all selected torsions.</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <group id="custom_torsion_group">
#                         <about>
#                             <enable>input.phase(structure_phase).group(build_polymer).group(advanced_tab).boolean(multiple_torsions)</enable>
#                             <label>Custom torsion specification</label>
#                             <description/>
#                         </about>
#                         <string id="custom_torsions">
#                             <about>
#                                 <label>Custom torsion probabilities</label>
#                                 <description>Example:
# # Torsion angle probabilities for monomer backbone; starting with
# # backbone atom 3, specify whether the torsion should change, and,
# # if so, how.
# # Values for specification:
# #   0: no change
# #   1: uniform probability for all angles
# #   2: energy levels associated with specific angles
# #   3: probability associated with specific angles
# 2                    # Torsion 3 specification: energies
# 5                    # 5 angle - energy pairs
#   1.5275  0.4609168  # ang (deg)  energy (kcal/mol)
#  73.8330  0.1364880
# 145.6294  0.0491418
# 219.4625  0.0602334
# 289.2220  0.1475796
# 0                    # Torsion 4 specification: no change
#
# If you are specifying torsion probabilities for more than one
# monomer, add a "# Monomer N" comment (where "N" is the index
# of the monomer, in the order specified on the Model tab) to
# the begnning of each section.
#                         </description>
#                             </about>
#                             <size>30x5</size>
#                             <default/>
#                             <current>None</current>
#                         </string>
#                     </group>
#                 </group>
#             </group>
#         </phase>
#         <phase id="simulation_phase">
#             <about>
#                 <label>Simulation</label>
#                 <description/>
#             </about>
#             <choice id="simulation_choice">
#                 <about>
#                     <label>Simulation choice</label>
#                     <description>Choose what happens when you click Simulate</description>
#                 </about>
#                 <option>
#                     <about>
#                         <label>Structure output only</label>
#                         <description>Output results from structure phase only; do not run LAMMPS</description>
#                     </about>
#                     <value>structure_only</value>
#                 </option>
#                 <option>
#                     <about>
#                         <label>LAMMPS input files only</label>
#                         <description>Download the generated LAMMPS input files, but do not run LAMMPS</description>
#                     </about>
#                     <value>lammps_files_only</value>
#                 </option>
#                 <option>
#                     <about>
#                         <label>Polymatic input files only</label>
#                         <description>Download input files for Polymatic</description>
#                     </about>
#                 </option>
#                 <option>
#                     <about>
#                         <label>Run LAMMPS on structure</label>
#                         <description/>
#                     </about>
#                     <value>run_lammps</value>
#                 </option>
#                 <default>run_lammps</default>
#                 <current>LAMMPS input files only</current>
#             </choice>
#             <group id="lammps_group">
#                 <about>
#                     <enable>input.phase(simulation_phase).choice(simulation_choice) != "structure_only"</enable>
#                     <label>LAMMPS</label>
#                     <description>Specify LAMMPS simulation parameters</description>
#                 </about>
#                 <group id="energy_expression">
#                     <about>
#                         <label>Energy Expression</label>
#                         <description>Specify how interactions betweens atoms are calculated</description>
#                     </about>
#                     <choice id="forcefield">
#                         <about>
#                             <label>Force field</label>
#                             <description>Determines what expression is used to caclulate interatomic potentials.</description>
#                         </about>
#                         <option>
#                             <about>
#                                 <label>Dreiding</label>
#                                 <description>A generic force field designed to give reasonably accurate results for a wide range of structures</description>
#                             </about>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>ReaxFF</label>
#                                 <description>Reactive forcefield</description>
#                             </about>
#                         </option>
#                         <default>Dreiding</default>
#                         <current>Dreiding</current>
#                     </choice>
#                     <number id="cutoff">
#                         <about>
#                             <label>Van der Waals Cutoff</label>
#                             <description>This sets the distance between atoms after which force field interactions are no longer calculated.</description>
#                         </about>
#                         <min>0</min>
#                         <units>A</units>
#                         <default>12A</default>
#                         <current>12A</current>
#                     </number>
#                     <number id="electro_cutoff">
#                         <about>
#                             <label>Electrostatic Cutoff</label>
#                             <description>This sets the distance between atoms beyond which electrostatic interactions are no longer calculated.</description>
#                         </about>
#                         <min>0</min>
#                         <units>A</units>
#                         <default>12A</default>
#                         <current>12A</current>
#                     </number>
#                     <choice id="electrostatic">
#                         <about>
#                             <label>Electrostatics</label>
#                             <description>This determines how electrostatic interactions between atoms are handled.</description>
#                         </about>
#                         <option>
#                             <about>
#                                 <label>PPPM</label>
#                                 <description>Uses kspace to calculate long range interactions between charges</description>
#                             </about>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>Cutoff</label>
#                                 <description>Long range interactions between charges are ignored using the cutoff dictated above.</description>
#                             </about>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>Ewald</label>
#                                 <description/>
#                             </about>
#                         </option>
#                         <default>PPPM</default>
#                         <current>PPPM</current>
#                     </choice>
#                     <number id="kspace">
#                         <about>
#                             <enable>input.phase(simulation_phase).group(lammps_group).group(energy_expression).choice(electrostatic) != "Cutoff"</enable>
#                             <label>kspace precision</label>
#                             <description>Specifies the number of kspace vectors for the Ewald method or the FFT grid size for the pppm style.</description>
#                         </about>
#                         <default>1e-4</default>
#                         <current>1e-4</current>
#                     </number>
#                     <group id="hidden">
#                         <about>
#                             <enable>no</enable>
#                         </about>
#                         <string id="dihedral">
#                             <about>
#                                 <label>Dihedral Coefficient Style</label>
#                                 <description>This sets what style lammps expects the dihedral coefficients to be in within the data file.</description>
#                             </about>
#                             <default>harmonic</default>
#                             <current>harmonic</current>
#                         </string>
#                         <string id="van_der_waals">
#                             <about>
#                                 <label>Van der Waals Interaction</label>
#                                 <description>This cointains the pair coefficients for van der waals interaction between atoms in the system.  For now this is filled automaticaly for the prebuilt models.</description>
#                             </about>
#                             <default>Van der Waals</default>
#                             <current>Van der Waals</current>
#                         </string>
#                         <string id="lammps_structure">
#                             <about>
#                                 <label>Structure file</label>
#                                 <description>This is the file containing the initial atom position</description>
#                             </about>
#                             <default>...</default>
#                             <current>...</current>
#                         </string>
#                         <string id="lammps_initial_pos">
#                             <about>
#                                 <label>Start Data</label>
#                                 <description>The data for the starting atom positions</description>
#                             </about>
#                             <default>...</default>
#                             <current>...</current>
#                         </string>
#                         <string id="typemap">
#                             <about>
#                                 <label>String of atom types</label>
#                             </about>
#                             <default>...</default>
#                             <current>...</current>
#                         </string>
#                         <string id="pair_coeffs">
#                             <about>
#                                 <label>String of pair coefficients</label>
#                             </about>
#                             <default>...</default>
#                             <current>...</current>
#                         </string>
#                     </group>
#                 </group>
#                 <group id="drivers">
#                     <about>
#                         <label>Drivers</label>
#                         <description>This tab contains information on what changes are being applied to the system such as changes in temperature and strains</description>
#                     </about>
#                     <group id="minimization_group">
#                         <about>
# ...
#                         </about>
#                         <units>atm</units>
#                         <default>1</default>
#                         <current>1</current>
#                     </number>
#                     <boolean id="deform">
#                         <about>
#                             <label>Deform system</label>
#                             <description>Stress or strain the system</description>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <group id="strain">
#                         <about>
#                             <enable>input.phase(simulation_phase).group(lammps_group).group(drivers).boolean(deform) == "yes"</enable>
#                             <label>Strain</label>
#                             <description>Specify deformation of the simulation box.  All strains are based on initial box dimensions.</description>
#                         </about>
#                         <choice id="strain_xx">
#                             <about>
#                                 <label>X direction</label>
#                             </about>
#                             <option>
#                                 <about>
#                                     <label>Engineering strain rate</label>
#                                 </about>
#                                 <value>erate</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>True strain rate</label>
#                                 </about>
#                                 <value>trate</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>Applied stress</label>
#                                 </about>
#                                 <value>stress</value>
#                             </option>
#                             <default>erate</default>
#                             <current>erate</current>
#                         </choice>
#                         <number id="strain_rate_xx">
#                             <about>
#                                 <enable>input.phase(simulation_phase).group(lammps_group).group(drivers).group(strain).choice(strain_xx) != "volume"</enable>
#                                 <label>X strain rate (1/ns)</label>
#                             </about>
#                             <units/>
#                             <default>0</default>
#                             <current>0</current>
#                         </number>
#                         <number id="stress_xx">
#                             <about>
#                                 <enable>input.phase(simulation_phase).group(lammps_group).group(drivers).group(strain).choice(strain_xx) == "stress"</enable>
#                                 <label>X stress</label>
#                             </about>
#                             <units>MPa</units>
#                             <default>1 atm</default>
#                             <current>1 atm</current>
#                         </number>
#                         <choice id="strain_yy">
#                             <about>
#                                 <label>Y direction</label>
#                             </about>
#                             <option>
#                                 <about>
#                                     <label>Engineering strain rate</label>
#                                 </about>
#                                 <value>erate</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>True strain rate</label>
#                                 </about>
#                                 <value>trate</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>Applied stress</label>
#                                 </about>
#                                 <value>stress</value>
#                             </option>
#                             <default>stress</default>
#                             <current>stress</current>
#                         </choice>
#                         <number id="strain_rate_yy">
#                             <about>
#                                 <enable>input.phase(simulation_phase).group(lammps_group).group(drivers).group(strain).choice(strain_yy) != "volume"</enable>
#                                 <label>Y strain rate (1/ns)</label>
#                             </about>
#                             <units/>
#                             <default>0</default>
#                             <current>0</current>
#                         </number>
#                         <number id="stress_yy">
#                             <about>
#                                 <enable>input.phase(simulation_phase).group(lammps_group).group(drivers).group(strain).choice(strain_yy) == "stress"</enable>
#                                 <label>Y stress</label>
#                             </about>
#                             <units>MPa</units>
#                             <default>1 atm</default>
#                             <current>1 atm</current>
#                         </number>
#                         <choice id="strain_zz">
#                             <about>
#                                 <label>Z direction</label>
#                             </about>
#                             <option>
#                                 <about>
#                                     <label>Engineering strain rate</label>
#                                 </about>
#                                 <value>erate</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>True strain rate</label>
#                                 </about>
#                                 <value>trate</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>Applied stress</label>
#                                 </about>
#                                 <value>stress</value>
#                             </option>
#                             <default>stress</default>
#                             <current>stress</current>
#                         </choice>
#                         <number id="strain_rate_zz">
#                             <about>
#                                 <enable>input.phase(simulation_phase).group(lammps_group).group(drivers).group(strain).choice(strain_zz) != "volume"</enable>
#                                 <label>Z strain rate (1/ns)</label>
#                             </about>
#                             <units/>
#                             <default>0</default>
#                             <current>0</current>
#                         </number>
#                         <number id="stress_zz">
#                             <about>
#                                 <enable>input.phase(simulation_phase).group(lammps_group).group(drivers).group(strain).choice(strain_zz) == "stress"</enable>
#                                 <label>Z stress</label>
#                             </about>
#                             <units>MPa</units>
#                             <default>1 atm</default>
#                             <current>1 atm</current>
#                         </number>
#                     </group>
#                     <group id="periodic_tasks">
#                         <about>
#                             <label>Periodic tasks</label>
#                             <description>Set how often the simulation performs events such as writiing to output</description>
#                         </about>
#                         <integer id="thermo_output">
#                             <about>
#                                 <label>MD steps between thermo outputs</label>
#                                 <description>The simulation will output thermodynamic variables to the output file every N timesteps.</description>
#                             </about>
#                             <default>10</default>
#                             <current>10</current>
#                         </integer>
#                         <integer id="traj_output">
#                             <about>
#                                 <label>MD steps between trajectory outputs</label>
#                                 <description>The simulation will output the current configuration of atoms to the trajectory file every N timesteps</description>
#                             </about>
#                             <default>100</default>
#                             <current>100</current>
#                         </integer>
#                         <integer id="neigh_list">
#                             <about>
#                                 <label>MD steps between neighbor list checks</label>
#                                 <description>The simulation defines the set of nearby atoms around any given atom as neighbors and as atoms change position these neighbors may change and the list must be updated.  This controls how often the list is upadated.</description>
#                             </about>
#                             <default>5</default>
#                             <current>5</current>
#                         </integer>
#                     </group>
#                     <boolean id="plot_density">
#                         <about>
#                             <label>Plot density vs. time</label>
#                         </about>
#                         <default>no</default>
#                         <current>no</current>
#                     </boolean>
#                     <group id="thermalize">
#                         <about>
#                             <label>Thermalization</label>
#                             <description>Options for thermalizing the system prior to the main MD simulation are here</description>
#                         </about>
#                         <boolean id="thermalize_check">
#                             <about>
#                                 <label>Thermalize system before MD run?</label>
#                                 <description>Thermalization will elevate the temperature of the system for a given time to allow atoms the chance to relax to lower energy configurations</description>
#                             </about>
#                             <default>no</default>
#                             <current>no</current>
#                         </boolean>
#                         <choice id="ensemble_thermalize">
#                             <about>
#                                 <label>Ensemble</label>
#                                 <description>Thermodynamic conditions for the simulation</description>
#                             </about>
#                             <option>
#                                 <about>
#                                     <label>NVT</label>
#                                     <description>Constant values for number of atoms, unit cell volume, and temperature</description>
#                                 </about>
#                                 <value>nvt</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>NPT</label>
#                                     <description>Constant values for number of atoms, stresses, and temperature</description>
#                                 </about>
#                                 <value>npt</value>
#                             </option>
#                             <option>
#                                 <about>
#                                     <label>NVE</label>
#                                     <description>Constant values for number of atoms, unit cell volume, and total energy</description>
#                                 </about>
#                                 <value>nve</value>
#                             </option>
#                             <default>NVT</default>
#                             <current>npt</current>
#                         </choice>
#                         <integer id="thermalize_steps">
#                             <about>
#                                 <label>Number of thermalization steps</label>
#                                 <description>This sets how long the thermalization of the system will run for.</description>
#                             </about>
#                             <default>1000</default>
#                             <current>1000</current>
#                         </integer>
#                     </group>
#                 </group>
#                 <group id="group_venue">
#                     <about>
#                         <label>Advanced options</label>
#                         <description>Specify where the LAMMPS simulations run</description>
#                     </about>
#                     <choice id="serial_parallel">
#                         <about>
#                             <label>Serial or parallel LAMMPS</label>
#                             <description>Choose to run serial LAMMPS or parallel LAMMPS; serial jobs will run immediately, but more slowly, while parallel jobs will run more quickly, but only after sitting in a queue.  Large systems with thousands of atoms should always run in parallel, to use distributed memory.</description>
#                         </about>
#                         <option>
#                             <about>
#                                 <label>Serial</label>
#                             </about>
#                             <value>serial</value>
#                         </option>
#                         <option>
#                             <about>
#                                 <label>Parallel</label>
#                             </about>
#                             <value>parallel</value>
#                         </option>
#                         <default>serial</default>
#                         <current>serial</current>
#                     </choice>
#                     <integer id="nnodes">
#                         <about>
#                             <enable>input.phase(simulation_phase).group(lammps_group).group(group_venue).choice(serial_parallel) == "parallel"</enable>
#                             <label>Number of cores</label>
#                             <description>Set the number of cores on which to run parallel LAMMPS</description>
#                         </about>
#                         <default>4</default>
#                         <current>4</current>
#                     </integer>
#                     <string id="walltime">
#                         <about>
#                             <enable>input.phase(simulation_phase).group(lammps_group).group(group_venue).choice(serial_parallel) == "parallel"</enable>
#                             <label>Simulation time</label>
#                             <description>Enter the maximum time for the simulation</description>
#                             <hints>Format: hh:mm:ss</hints>
#                             <size>30x1</size>
#                         </about>
#                         <default>01:00:00</default>
#                         <current>01:00:00</current>
#                     </string>
#                 </group>
#             </group>
#         </phase>
#     </input>
#     <output>
#         <log>Program finished: non-zero exit code is 1
#
# /apps/polymod/r457/rappture/../bin/polymod.rb:261:in `&lt;main&gt;': undefined method `include?' for nil:NilClass (NoMethodError)
# </log>
#         <status>failed</status>
#         <time>Thu Jul 19 10:30:58 PM EDT 2018</time>
#         <filename>/home/nanohub/dcelbert/data/results/1336183/run.xml</filename>
#         <version>1.7</version>
#         <user>dcelbert</user>
#     </output>
# </run>

# %%
# View the initial structure built by PolymerModeler
import nglview as nv
import subprocess as sp

tmp_pdb = 'temp.pdb'
polymod_pdb = 'polymod.pdb'
with open(tmp_pdb, 'w') as f:
    f.write(get_results('Built structures, unwrapped'))
sp.call(['babel', tmp_pdb, polymod_pdb])  # add CONECT records
v = nv.show_structure_file(polymod_pdb)
v.representations = [{'type': 'ball+stick', 'params': {}}]
v.parameters = {'backgroundColor': 'black'}
v

# %%
# Relax and thermalize the initial structure built by PolymerModeler
import hublib.use
# %use lammps-15May15

nodes = 2
walltime = '1:00:00'
datafile = 'polymer_relax.data'
with open(datafile, 'w') as f:
    f.write(task.get_output_value('LAMMPS data file'))
infile = 'lammps_relax.in'
with open(infile, 'w') as f:
    f.write(task.get_output_value('LAMMPS input file'))

# !submit -n $nodes -w $walltime -i $datafile lammps-15May15-parallel -in $infile

# %%
# Cool and compress the structure with LAMMPS
infile = 'lammps_cool.in'
T_steps = 10000
lammps_input = """
read_restart      restart.lammps

neighbor          2.0 bin
thermo_style      custom temp density vol etotal ke pe ebond eangle edihed eimp evdwl ecoul elong press pxx pyy pzz pxy pxz pyz lx ly lz
thermo            100
thermo_modify     flush yes line multi format float %16.6g

timestep          4
neigh_modify      every 1 delay 5
kspace_style      pppm 1e-4
run_style         respa 3 2 2 bond 1 pair 2 kspace 3
velocity          all create 800.0 1214556 mom yes rot yes dist gaussian

# Loop
variable          i loop 26
label             loopa
reset_timestep    0
variable          T equal 800+($i-1)*(-20)

fix               1 all npt temp $T $T 100.0 iso 1.0 1.0 1000.
dump              2 all custom 500 strcool_$TK.dump id type x y z
run               {0}
write_data        str_cool$TK.data
unfix             1
undump            2
next              i
jump              {1} loopa
""".format(T_steps, infile)

with open(infile, 'w' ) as f:
    f.write(lammps_input)
walltime = '12:00:00'

# !submit -n $nodes -w $walltime -i restart.lammps lammps-15May15-parallel -in $infile

# %%
# Extract the density and temperature data from LAMMPS output; find Tg
from Tgcalc import getVDT, getVDTdata, getTg_BL
import matplotlib.pyplot as plt
# %matplotlib notebook

getVDT('log.lammps', T_steps)
data_file = 'log.rec_VDT'

# Plot density vs. T
T, rho, err = getVDTdata(data_file)
plt.style.use('ggplot')
plt.plot(T, rho, 'b-')
plt.xlabel('T (K)')
plt.ylabel('Density (g/cc)')
plt.show()

# Calculate Tg
print 'Tg from bilinear fit:', getTg_BL(data_file)
